# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

import datetime as dt

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
from sklearn.linear_model import ElasticNet
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVR
from itertools import product
from scipy import stats
import statsmodels.api as sm
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['product', 'clf']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
df = pd.read_csv('C:/Users/user/Desktop/Practice-2020-master/VASYA4.csv')
plt.figure(figsize(15,7))
df.id.plot()
plt.ylabel('RTSI')
pylab.show()

# %%
X = df.drop('month',axis=1)
y = df.month

# %%
X = pd.get_dummies(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from sklearn import tree
from sklearn.datasets import load_iris

# %%
clf = tree.DecisionTreeClassifier()

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_train,y_train)
# Out:
# 0.7430555555555556

# %%
clf.fit(X_test,y_test)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy',max_depth = 3)

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
clf.score(X_train,y_train)
# Out:
# 0.05555555555555555

# %%
clf.fit(X_test,y_test)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
clf.score(X_test,y_test)
# Out:
# 0.08333333333333333
